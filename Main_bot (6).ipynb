# %% [markdown]
# # **Crypto money analytics bot**

# %% [markdown]
# ### **installing required libraries**

# %%
import pandas as pd
import numpy as np
from bs4 import BeautifulSoup 
from selenium import webdriver  # pip install selenium
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager  # pip install webdriver-manager
import re

# %%
import telebot
import requests

# %% [markdown]
# ## Developing bot

# %%
bot = telebot.TeleBot('TOKEN')

@bot.message_handler(commands = ['start'])
def start(message):
    bot.send_message(message.chat.id, 'Hello! It`s new telegram crypto bot. to check does crypto got yout price limit enter /set_data')
    
         
         
@bot.message_handler(commands = ['set_data'])
def func3(message):
    msg = bot.send_message(message.chat.id, text = 'Enter data in format price1/condition1/currency1,price2/condition2/currency2 ..... : ')
    bot.register_next_step_handler(msg, Is_got)   


@bot.message_handler(commands = ['is_got'])
def Is_got(message):
    user_text = message.text
    do_break = 0 
    
    global currency_dict
    currency_dict = {}
    
    for n, i in enumerate(user_text.split(',')):
        currency_dict["currency" + str(n)]  = 0
    
    while True:
            for n, bc in enumerate(user_text.split(',')):
                            df = pd.read_csv("bot_file.csv")
                           
                            global do_broke
                            do_broke = 0
                        
                            if list(df["a"])[0] == 1:
                                do_broke = 1
                            b1 = bc.split('/')
                            user_price = b1[0]
                            ml = b1[1]
                            user_currency = b1[2]
                        #try:
                            with webdriver.Chrome(service=Service(ChromeDriverManager().install())) as driver:  # open chrome
                                driver.get('https://www.binance.com/en/price/' + str(user_currency))  # open page
                                time.sleep(3)  # time to load webpage
                                soup = BeautifulSoup(driver.page_source, 'html.parser') 
    
                            for n, i1 in enumerate(list(soup("div"))):
                                if i1.get("id") == "__APP":
                                    for n1,i in enumerate(list(i1("section"))):
                                        if i.get("class") == ['css-2tpvhp']:
                                            for a in i('div'):
                                                if a.get("class") == ["css-1ovykgb"]:
                                                    for b in list(a("div")):
                                                        if b.get("class") == ["css-1xmcoai"]:
                                                            for c in b("div"):
                                                                if c.get("class") == ["css-197puc0"]:
                                                                    for d in c("div"):
                                                                        if d.get("class") == ["css-1267ixm"]:
                                                                            for e in d("div"):
                                                                                if e.get("class") == ["css-1bwgsh3"]:
                                                                                    real_price = e    
                            
        
                            real_price = str(real_price)
                            real_price = real_price[real_price.index("$") + 1:].replace("</div>", '')
                            
                            real_price = real_price.replace(",", "") 
                            
                            if ml == 'less' and float(real_price) <= float(user_price):                                
                                bot.send_message(message.chat.id, text = 'The price of ' +  str(user_currency)  + ' got your limit ')
                                do_break = do_break + 1

                            elif ml == 'more' and float(real_price) >= float(user_price):                                
                                bot.send_message(message.chat.id, text = 'The price of ' +  str(user_currency)  + ' got your limit ')
                                do_break = do_break + 1

                                                   
            if do_break == len(user_text.split(',')) or do_broke == 1 :
                break
                
            do_break = 0
                        #except:          
                                #bot.send_message(message.chat.id, text = 'there is no crypto with this name')  

                    
    #time.sleep(300)

if __name__ == '__main__':
    bot.polling(none_stop = True)
# Out:
# 2024-05-14 22:14:10,711 (__init__.py:1021 MainThread) ERROR - TeleBot: "Infinity polling exception: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found"
# 2024-05-14 22:14:10,715 (__init__.py:1023 MainThread) ERROR - TeleBot: "Exception traceback:
# Traceback (most recent call last):
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1016, in infinity_polling
#     self.polling(non_stop=True, timeout=timeout, long_polling_timeout=long_polling_timeout,
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1101, in polling
#     logger.info('Starting your bot with username: [@%s]', self.user.username)
#                                                           ^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 279, in user
#     self._user = self.get_me()
#                  ^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1288, in get_me
#     apihelper.get_me(self.token)
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 198, in get_me
#     return _make_request(token, method_url)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 164, in _make_request
#     json_result = _check_result(method_name, result)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 191, in _check_result
#     raise ApiTelegramException(method_name, result, result_json)
# telebot.apihelper.ApiTelegramException: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found
# "
# 2024-05-14 22:14:13,755 (__init__.py:1021 MainThread) ERROR - TeleBot: "Infinity polling exception: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found"
# 2024-05-14 22:14:13,756 (__init__.py:1023 MainThread) ERROR - TeleBot: "Exception traceback:
# Traceback (most recent call last):
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1016, in infinity_polling
#     self.polling(non_stop=True, timeout=timeout, long_polling_timeout=long_polling_timeout,
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1101, in polling
#     logger.info('Starting your bot with username: [@%s]', self.user.username)
#                                                           ^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 279, in user
#     self._user = self.get_me()
#                  ^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1288, in get_me
#     apihelper.get_me(self.token)
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 198, in get_me
#     return _make_request(token, method_url)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 164, in _make_request
#     json_result = _check_result(method_name, result)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 191, in _check_result
#     raise ApiTelegramException(method_name, result, result_json)
# telebot.apihelper.ApiTelegramException: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found
# "
# 2024-05-14 22:14:16,810 (__init__.py:1021 MainThread) ERROR - TeleBot: "Infinity polling exception: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found"
# 2024-05-14 22:14:16,811 (__init__.py:1023 MainThread) ERROR - TeleBot: "Exception traceback:
# Traceback (most recent call last):
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1016, in infinity_polling
#     self.polling(non_stop=True, timeout=timeout, long_polling_timeout=long_polling_timeout,
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1101, in polling
#     logger.info('Starting your bot with username: [@%s]', self.user.username)
#                                                           ^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 279, in user
#     self._user = self.get_me()
#                  ^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1288, in get_me
#     apihelper.get_me(self.token)
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 198, in get_me
#     return _make_request(token, method_url)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 164, in _make_request
#     json_result = _check_result(method_name, result)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 191, in _check_result
#     raise ApiTelegramException(method_name, result, result_json)
# telebot.apihelper.ApiTelegramException: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found
# "
# 2024-05-14 22:14:19,885 (__init__.py:1021 MainThread) ERROR - TeleBot: "Infinity polling exception: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found"
# 2024-05-14 22:14:19,886 (__init__.py:1023 MainThread) ERROR - TeleBot: "Exception traceback:
# Traceback (most recent call last):
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1016, in infinity_polling
#     self.polling(non_stop=True, timeout=timeout, long_polling_timeout=long_polling_timeout,
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1101, in polling
#     logger.info('Starting your bot with username: [@%s]', self.user.username)
#                                                           ^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 279, in user
#     self._user = self.get_me()
#                  ^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1288, in get_me
#     apihelper.get_me(self.token)
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 198, in get_me
#     return _make_request(token, method_url)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 164, in _make_request
#     json_result = _check_result(method_name, result)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 191, in _check_result
#     raise ApiTelegramException(method_name, result, result_json)
# telebot.apihelper.ApiTelegramException: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found
# "
# 2024-05-14 22:14:22,927 (__init__.py:1021 MainThread) ERROR - TeleBot: "Infinity polling exception: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found"
# 2024-05-14 22:14:22,928 (__init__.py:1023 MainThread) ERROR - TeleBot: "Exception traceback:
# Traceback (most recent call last):
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1016, in infinity_polling
#     self.polling(non_stop=True, timeout=timeout, long_polling_timeout=long_polling_timeout,
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1101, in polling
#     logger.info('Starting your bot with username: [@%s]', self.user.username)
#                                                           ^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 279, in user
#     self._user = self.get_me()
#                  ^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1288, in get_me
#     apihelper.get_me(self.token)
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 198, in get_me
#     return _make_request(token, method_url)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 164, in _make_request
#     json_result = _check_result(method_name, result)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 191, in _check_result
#     raise ApiTelegramException(method_name, result, result_json)
# telebot.apihelper.ApiTelegramException: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found
# "
# 2024-05-14 22:14:25,968 (__init__.py:1021 MainThread) ERROR - TeleBot: "Infinity polling exception: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found"
# 2024-05-14 22:14:25,969 (__init__.py:1023 MainThread) ERROR - TeleBot: "Exception traceback:
# Traceback (most recent call last):
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1016, in infinity_polling
#     self.polling(non_stop=True, timeout=timeout, long_polling_timeout=long_polling_timeout,
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1101, in polling
#     logger.info('Starting your bot with username: [@%s]', self.user.username)
#                                                           ^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 279, in user
#     self._user = self.get_me()
#                  ^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1288, in get_me
#     apihelper.get_me(self.token)
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 198, in get_me
#     return _make_request(token, method_url)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 164, in _make_request
#     json_result = _check_result(method_name, result)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 191, in _check_result
#     raise ApiTelegramException(method_name, result, result_json)
# telebot.apihelper.ApiTelegramException: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found
# "
# 2024-05-14 22:14:29,011 (__init__.py:1021 MainThread) ERROR - TeleBot: "Infinity polling exception: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found"
# 2024-05-14 22:14:29,012 (__init__.py:1023 MainThread) ERROR - TeleBot: "Exception traceback:
# Traceback (most recent call last):
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1016, in infinity_polling
#     self.polling(non_stop=True, timeout=timeout, long_polling_timeout=long_polling_timeout,
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1101, in polling
#     logger.info('Starting your bot with username: [@%s]', self.user.username)
#                                                           ^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 279, in user
#     self._user = self.get_me()
#                  ^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1288, in get_me
#     apihelper.get_me(self.token)
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 198, in get_me
#     return _make_request(token, method_url)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 164, in _make_request
#     json_result = _check_result(method_name, result)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 191, in _check_result
#     raise ApiTelegramException(method_name, result, result_json)
# telebot.apihelper.ApiTelegramException: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found
# "
# 2024-05-14 22:14:32,051 (__init__.py:1021 MainThread) ERROR - TeleBot: "Infinity polling exception: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found"
# 2024-05-14 22:14:32,053 (__init__.py:1023 MainThread) ERROR - TeleBot: "Exception traceback:
# Traceback (most recent call last):
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1016, in infinity_polling
#     self.polling(non_stop=True, timeout=timeout, long_polling_timeout=long_polling_timeout,
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1101, in polling
#     logger.info('Starting your bot with username: [@%s]', self.user.username)
#                                                           ^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 279, in user
#     self._user = self.get_me()
#                  ^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1288, in get_me
#     apihelper.get_me(self.token)
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 198, in get_me
#     return _make_request(token, method_url)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 164, in _make_request
#     json_result = _check_result(method_name, result)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 191, in _check_result
#     raise ApiTelegramException(method_name, result, result_json)
# telebot.apihelper.ApiTelegramException: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found
# "
# 2024-05-14 22:14:35,096 (__init__.py:1021 MainThread) ERROR - TeleBot: "Infinity polling exception: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found"
# 2024-05-14 22:14:35,096 (__init__.py:1023 MainThread) ERROR - TeleBot: "Exception traceback:
# Traceback (most recent call last):
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1016, in infinity_polling
#     self.polling(non_stop=True, timeout=timeout, long_polling_timeout=long_polling_timeout,
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1101, in polling
#     logger.info('Starting your bot with username: [@%s]', self.user.username)
#                                                           ^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 279, in user
#     self._user = self.get_me()
#                  ^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1288, in get_me
#     apihelper.get_me(self.token)
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 198, in get_me
#     return _make_request(token, method_url)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 164, in _make_request
#     json_result = _check_result(method_name, result)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 191, in _check_result
#     raise ApiTelegramException(method_name, result, result_json)
# telebot.apihelper.ApiTelegramException: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found
# "
# 2024-05-14 22:14:38,137 (__init__.py:1021 MainThread) ERROR - TeleBot: "Infinity polling exception: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found"
# 2024-05-14 22:14:38,138 (__init__.py:1023 MainThread) ERROR - TeleBot: "Exception traceback:
# Traceback (most recent call last):
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1016, in infinity_polling
#     self.polling(non_stop=True, timeout=timeout, long_polling_timeout=long_polling_timeout,
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1101, in polling
#     logger.info('Starting your bot with username: [@%s]', self.user.username)
#                                                           ^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 279, in user
#     self._user = self.get_me()
#                  ^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1288, in get_me
#     apihelper.get_me(self.token)
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 198, in get_me
#     return _make_request(token, method_url)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 164, in _make_request
#     json_result = _check_result(method_name, result)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 191, in _check_result
#     raise ApiTelegramException(method_name, result, result_json)
# telebot.apihelper.ApiTelegramException: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found
# "
# 2024-05-14 22:14:41,397 (__init__.py:1021 MainThread) ERROR - TeleBot: "Infinity polling exception: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found"
# 2024-05-14 22:14:41,398 (__init__.py:1023 MainThread) ERROR - TeleBot: "Exception traceback:
# Traceback (most recent call last):
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1016, in infinity_polling
#     self.polling(non_stop=True, timeout=timeout, long_polling_timeout=long_polling_timeout,
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1101, in polling
#     logger.info('Starting your bot with username: [@%s]', self.user.username)
#                                                           ^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 279, in user
#     self._user = self.get_me()
#                  ^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1288, in get_me
#     apihelper.get_me(self.token)
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 198, in get_me
#     return _make_request(token, method_url)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 164, in _make_request
#     json_result = _check_result(method_name, result)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 191, in _check_result
#     raise ApiTelegramException(method_name, result, result_json)
# telebot.apihelper.ApiTelegramException: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found
# "
# 2024-05-14 22:14:44,438 (__init__.py:1021 MainThread) ERROR - TeleBot: "Infinity polling exception: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found"
# 2024-05-14 22:14:44,439 (__init__.py:1023 MainThread) ERROR - TeleBot: "Exception traceback:
# Traceback (most recent call last):
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1016, in infinity_polling
#     self.polling(non_stop=True, timeout=timeout, long_polling_timeout=long_polling_timeout,
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1101, in polling
#     logger.info('Starting your bot with username: [@%s]', self.user.username)
#                                                           ^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 279, in user
#     self._user = self.get_me()
#                  ^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1288, in get_me
#     apihelper.get_me(self.token)
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 198, in get_me
#     return _make_request(token, method_url)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 164, in _make_request
#     json_result = _check_result(method_name, result)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 191, in _check_result
#     raise ApiTelegramException(method_name, result, result_json)
# telebot.apihelper.ApiTelegramException: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found
# "
# 2024-05-14 22:14:47,483 (__init__.py:1021 MainThread) ERROR - TeleBot: "Infinity polling exception: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found"
# 2024-05-14 22:14:47,484 (__init__.py:1023 MainThread) ERROR - TeleBot: "Exception traceback:
# Traceback (most recent call last):
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1016, in infinity_polling
#     self.polling(non_stop=True, timeout=timeout, long_polling_timeout=long_polling_timeout,
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1101, in polling
#     logger.info('Starting your bot with username: [@%s]', self.user.username)
#                                                           ^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 279, in user
#     self._user = self.get_me()
#                  ^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1288, in get_me
#     apihelper.get_me(self.token)
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 198, in get_me
#     return _make_request(token, method_url)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 164, in _make_request
#     json_result = _check_result(method_name, result)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 191, in _check_result
#     raise ApiTelegramException(method_name, result, result_json)
# telebot.apihelper.ApiTelegramException: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found
# "
# 2024-05-14 22:14:50,524 (__init__.py:1021 MainThread) ERROR - TeleBot: "Infinity polling exception: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found"
# 2024-05-14 22:14:50,525 (__init__.py:1023 MainThread) ERROR - TeleBot: "Exception traceback:
# Traceback (most recent call last):
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1016, in infinity_polling
#     self.polling(non_stop=True, timeout=timeout, long_polling_timeout=long_polling_timeout,
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1101, in polling
#     logger.info('Starting your bot with username: [@%s]', self.user.username)
#                                                           ^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 279, in user
#     self._user = self.get_me()
#                  ^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1288, in get_me
#     apihelper.get_me(self.token)
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 198, in get_me
#     return _make_request(token, method_url)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 164, in _make_request
#     json_result = _check_result(method_name, result)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 191, in _check_result
#     raise ApiTelegramException(method_name, result, result_json)
# telebot.apihelper.ApiTelegramException: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found
# "
# 2024-05-14 22:14:53,565 (__init__.py:1021 MainThread) ERROR - TeleBot: "Infinity polling exception: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found"
# 2024-05-14 22:14:53,566 (__init__.py:1023 MainThread) ERROR - TeleBot: "Exception traceback:
# Traceback (most recent call last):
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1016, in infinity_polling
#     self.polling(non_stop=True, timeout=timeout, long_polling_timeout=long_polling_timeout,
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1101, in polling
#     logger.info('Starting your bot with username: [@%s]', self.user.username)
#                                                           ^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 279, in user
#     self._user = self.get_me()
#                  ^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1288, in get_me
#     apihelper.get_me(self.token)
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 198, in get_me
#     return _make_request(token, method_url)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 164, in _make_request
#     json_result = _check_result(method_name, result)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 191, in _check_result
#     raise ApiTelegramException(method_name, result, result_json)
# telebot.apihelper.ApiTelegramException: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found
# "
# 2024-05-14 22:14:56,777 (__init__.py:1021 MainThread) ERROR - TeleBot: "Infinity polling exception: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found"
# 2024-05-14 22:14:56,779 (__init__.py:1023 MainThread) ERROR - TeleBot: "Exception traceback:
# Traceback (most recent call last):
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1016, in infinity_polling
#     self.polling(non_stop=True, timeout=timeout, long_polling_timeout=long_polling_timeout,
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1101, in polling
#     logger.info('Starting your bot with username: [@%s]', self.user.username)
#                                                           ^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 279, in user
#     self._user = self.get_me()
#                  ^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1288, in get_me
#     apihelper.get_me(self.token)
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 198, in get_me
#     return _make_request(token, method_url)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 164, in _make_request
#     json_result = _check_result(method_name, result)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 191, in _check_result
#     raise ApiTelegramException(method_name, result, result_json)
# telebot.apihelper.ApiTelegramException: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found
# "
# 2024-05-14 22:14:59,821 (__init__.py:1021 MainThread) ERROR - TeleBot: "Infinity polling exception: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found"
# 2024-05-14 22:14:59,822 (__init__.py:1023 MainThread) ERROR - TeleBot: "Exception traceback:
# Traceback (most recent call last):
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1016, in infinity_polling
#     self.polling(non_stop=True, timeout=timeout, long_polling_timeout=long_polling_timeout,
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1101, in polling
#     logger.info('Starting your bot with username: [@%s]', self.user.username)
#                                                           ^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 279, in user
#     self._user = self.get_me()
#                  ^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1288, in get_me
#     apihelper.get_me(self.token)
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 198, in get_me
#     return _make_request(token, method_url)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 164, in _make_request
#     json_result = _check_result(method_name, result)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 191, in _check_result
#     raise ApiTelegramException(method_name, result, result_json)
# telebot.apihelper.ApiTelegramException: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found
# "
# 2024-05-14 22:15:02,864 (__init__.py:1021 MainThread) ERROR - TeleBot: "Infinity polling exception: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found"
# 2024-05-14 22:15:02,865 (__init__.py:1023 MainThread) ERROR - TeleBot: "Exception traceback:
# Traceback (most recent call last):
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1016, in infinity_polling
#     self.polling(non_stop=True, timeout=timeout, long_polling_timeout=long_polling_timeout,
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1101, in polling
#     logger.info('Starting your bot with username: [@%s]', self.user.username)
#                                                           ^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 279, in user
#     self._user = self.get_me()
#                  ^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\__init__.py", line 1288, in get_me
#     apihelper.get_me(self.token)
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 198, in get_me
#     return _make_request(token, method_url)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 164, in _make_request
#     json_result = _check_result(method_name, result)
#                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\1\anaconda3\Lib\site-packages\telebot\apihelper.py", line 191, in _check_result
#     raise ApiTelegramException(method_name, result, result_json)
# telebot.apihelper.ApiTelegramException: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found
# "
# ---------------------------------------------------------------------------
# ApiTelegramException                      Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\telebot\__init__.py:1016, in TeleBot.infinity_polling(self, timeout, skip_pending, long_polling_timeout, logger_level, allowed_updates, restart_on_change, path_to_watch, *args, **kwargs)
#    1015 try:
# -> 1016     self.polling(non_stop=True, timeout=timeout, long_polling_timeout=long_polling_timeout,
#    1017                  logger_level=logger_level, allowed_updates=allowed_updates, restart_on_change=False,
#    1018                  *args, **kwargs)
#    1019 except Exception as e:
#
# File ~\anaconda3\Lib\site-packages\telebot\__init__.py:1101, in TeleBot.polling(self, non_stop, skip_pending, interval, timeout, long_polling_timeout, logger_level, allowed_updates, none_stop, restart_on_change, path_to_watch)
#    1099     self._setup_change_detector(path_to_watch)
# -> 1101 logger.info('Starting your bot with username: [@%s]', self.user.username)
#    1103 if self.threaded:
#
# File ~\anaconda3\Lib\site-packages\telebot\__init__.py:279, in TeleBot.user(self)
#     278 if not self._user:
# --> 279     self._user = self.get_me()
#     280 return self._user
#
# File ~\anaconda3\Lib\site-packages\telebot\__init__.py:1288, in TeleBot.get_me(self)
#    1281 """
#    1282 A simple method for testing your bot's authentication token. Requires no parameters.
#    1283 Returns basic information about the bot in form of a User object.
#    1284
#    1285 Telegram documentation: https://core.telegram.org/bots/api#getme
#    1286 """
#    1287 return types.User.de_json(
# -> 1288     apihelper.get_me(self.token)
#    1289 )
#
# File ~\anaconda3\Lib\site-packages\telebot\apihelper.py:198, in get_me(token)
#     197 method_url = r'getMe'
# --> 198 return _make_request(token, method_url)
#
# File ~\anaconda3\Lib\site-packages\telebot\apihelper.py:164, in _make_request(token, method_name, method, params, files)
#     162 logger.debug("The server returned: '{0}'".format(result.text.encode('utf8')))
# --> 164 json_result = _check_result(method_name, result)
#     165 if json_result:
#
# File ~\anaconda3\Lib\site-packages\telebot\apihelper.py:191, in _check_result(method_name, result)
#     190 if not result_json['ok']:
# --> 191     raise ApiTelegramException(method_name, result, result_json)
#     193 return result_json
#
# ApiTelegramException: A request to the Telegram API was unsuccessful. Error code: 404. Description: Not Found
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 87
#      80                         #except:
#      81                                 #bot.send_message(message.chat.id, text = 'there is no crypto with this name')
#      82
#      83
#      84     #time.sleep(300)
#      86 if __name__ == '__main__':
# ---> 87     bot.infinity_polling(none_stop = True)
#
# File ~\anaconda3\Lib\site-packages\telebot\__init__.py:1024, in TeleBot.infinity_polling(self, timeout, skip_pending, long_polling_timeout, logger_level, allowed_updates, restart_on_change, path_to_watch, *args, **kwargs)
#    1022     if logger_level and logger_level >= logging.DEBUG:
#    1023         logger.error("Exception traceback:\n%s", traceback.format_exc())
# -> 1024     time.sleep(3)
#    1025     continue
#    1026 if logger_level and logger_level >= logging.INFO:
#
# KeyboardInterrupt:
